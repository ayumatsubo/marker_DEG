# %%
load('Normal_epi_markers_20190905.RData')
load('Normal_epi_Seurat_20190905.RData')

# %%
library(Seurat)
library(Matrix)
library(ggplot2)
library(cowplot)
library(dplyr)
library(enrichR)
# Out:
# ********************************************************
# Note: As of version 1.0.0, cowplot does not change the
#   default ggplot2 theme anymore. To recover the previous
#   behavior, execute:
#   theme_set(theme_cowplot())
# ********************************************************
#
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
reticulate::import(module = "umap")
# Out:
# Module(umap)

# %%
DimPlot(stomach_epithelial, as_label=FALSE)
# Out:
# The following functions and any applicable methods accept the dots: CombinePlots
# plot without title

# %% [markdown]
# # #0 foveola epithelium

# %%
stomach.markers %>% filter(cluster==0)
# Out:
#    p_val         avg_logFC pct.1 pct.2 p_val_adj     cluster gene
# 1  7.470519e-151 0.9572275 0.960 0.606 1.363146e-146 0       GKN1
# 2  9.436369e-140 0.7049030 0.939 0.490 1.721854e-135 0       GKN2
# 3  3.847529e-123 0.6697871 0.999 0.720 7.020587e-119 0       TFF1
# 4   4.779954e-85 0.4940597 0.911 0.557  8.721982e-81 0       TFF2
# 5   1.445114e-72 0.4507512 0.838 0.538  2.636899e-68 0       CA2
# 6   2.125028e-66 0.4905357 0.701 0.422  3.877538e-62 0       RNASE1
# 7   1.316984e-63 0.4210754 0.908 0.621  2.403100e-59 0       S100P
# 8   4.328370e-62 0.4112330 0.912 0.555  7.897978e-58 0       MUC5AC
# 9   4.938358e-54 0.3119208 0.917 0.653  9.011022e-50 0       MUC1
# 10  6.798618e-54 0.4572027 0.953 0.812  1.240544e-49 0       JCHAIN
# 11  2.797308e-53 0.4146841 0.994 0.899  5.104248e-49 0       IGHA1
# 12  5.904029e-48 0.4923590 0.979 0.861  1.077308e-43 0       IGKC
# 13  5.360524e-46 0.4023777 0.855 0.628  9.781348e-42 0       PSCA
# ...

# %% [markdown]
# # #1 foveolaだと思うが・・・

# %%
stomach.markers %>% filter(cluster==1)
# Out:
#    p_val         avg_logFC pct.1 pct.2 p_val_adj     cluster gene
# 1  5.148861e-297 1.5766931 1.000 0.880 9.395126e-293 1       MALAT1
# 2  1.959867e-255 1.3471762 0.986 0.653 3.576169e-251 1       NEAT1
# 3  1.523117e-182 0.7568613 0.738 0.253 2.779231e-178 1       LIPH
# 4  6.602472e-106 0.5376855 0.541 0.191 1.204753e-101 1       CAPN8
# 5   6.216160e-86 0.5977116 0.704 0.382  1.134263e-81 1       ELF3
# 6   2.275978e-81 0.4173685 0.501 0.193  4.152976e-77 1       CYP3A5
# 7   3.463723e-76 0.4022595 0.469 0.175  6.320255e-72 1       SYTL2
# 8   5.835546e-76 0.4353117 0.346 0.099  1.064812e-71 1       ANKRD36C
# 9   4.023512e-74 0.5230701 0.606 0.297  7.341702e-70 1       KLF6
# 10  2.443043e-70 0.5210808 0.577 0.291  4.457821e-66 1       VMP1
# 11  1.543993e-61 0.3789179 0.928 0.558  2.817324e-57 1       MUC5AC
# 12  7.240607e-58 0.4397328 0.570 0.299  1.321194e-53 1       JUN
# 13  9.641702e-54 0.3445000 0.366 0.139  1.759321e-49 1       SLC5A5
# ...

# %% [markdown]
# # #2 foveolar

# %%
stomach.markers %>% filter(cluster==2)
# Out:
#    p_val         avg_logFC pct.1 pct.2 p_val_adj     cluster gene
# 1  2.043486e-217 1.2035075 0.991 0.646 3.728749e-213 2       MUC1
# 2  1.139512e-147 0.8480503 0.685 0.236 2.079267e-143 2       DUOX2
# 3  4.514111e-146 0.7411249 0.545 0.145 8.236898e-142 2       PSAPL1
# 4  2.888931e-142 0.9079406 0.987 0.550 5.271432e-138 2       MUC5AC
# 5  1.465900e-138 0.9984257 0.961 0.616 2.674828e-134 2       PSCA
# 6  2.387848e-123 0.5830092 0.506 0.146 4.357107e-119 2       APOL1
# 7  5.605946e-109 0.7303999 0.976 0.609 1.022917e-104 2       GKN1
# 8  3.017025e-102 0.6804330 0.928 0.500  5.505165e-98 2       GKN2
# 9  7.975804e-102 0.5101493 0.517 0.169  1.455345e-97 2       CEACAM5
# 10  9.744979e-95 0.6416257 0.812 0.471  1.778166e-90 2       CLDN18
# 11  1.859377e-93 0.3724196 0.404 0.111  3.392805e-89 2       GPX3
# 12  3.122764e-93 0.6564972 0.869 0.560  5.698108e-89 2       HLA-A
# 13  1.097994e-87 0.5429907 0.999 0.724  2.003509e-83 2       TFF1
# ...

# %% [markdown]
# # #3  APOA1-4→HDLの主要な構成タンパク？
#       腺のなかでもけっこうちがいそう

# %%
stomach.markers %>% filter(cluster==3)
# Out:
#     p_val         avg_logFC pct.1 pct.2 p_val_adj     cluster gene
# 1    0.000000e+00 2.6013874 0.626 0.057  0.000000e+00 3       APOA1
# 2    0.000000e+00 2.3517467 0.596 0.034  0.000000e+00 3       APOA4
# 3    0.000000e+00 2.1198196 0.498 0.034  0.000000e+00 3       APOC3
# 4    0.000000e+00 2.0562109 0.822 0.076  0.000000e+00 3       PRAP1
# 5    0.000000e+00 1.7699191 0.776 0.094  0.000000e+00 3       FABP1
# 6    0.000000e+00 1.6412967 0.779 0.050  0.000000e+00 3       ANPEP
# 7    0.000000e+00 1.4290267 0.636 0.061  0.000000e+00 3       SERPINA1
# 8    0.000000e+00 1.4185079 0.658 0.039  0.000000e+00 3       FABP2
# 9    0.000000e+00 1.3981359 0.551 0.031  0.000000e+00 3       RBP2
# 10   0.000000e+00 1.1460748 0.645 0.038  0.000000e+00 3       ALDOB
# 11   0.000000e+00 1.0673805 0.652 0.031  0.000000e+00 3       TM4SF20
# 12   0.000000e+00 1.0454677 0.626 0.026  0.000000e+00 3       SI
# 13   0.000000e+00 1.0137248 0.731 0.116  0.000000e+00 3       CDHR5
# ...

# %% [markdown]
# # #4

# %%
stomach.markers %>% filter(cluster==4)
# Out:
#    p_val         avg_logFC pct.1 pct.2 p_val_adj     cluster gene
# 1  1.541162e-144 0.8583255 0.976 0.535 2.812159e-140 4       CA2
# 2  4.447531e-133 0.8792686 0.986 0.563 8.115410e-129 4       MUC5AC
# 3  3.341514e-131 0.7183776 0.857 0.402 6.097261e-127 4       ANXA10
# 4  1.362549e-107 0.6332704 0.754 0.320 2.486243e-103 4       FCGBP
# 5  5.555294e-107 0.8856994 0.929 0.512 1.013675e-102 4       GKN2
# 6  4.238082e-104 0.8537247 0.725 0.308 7.733228e-100 4       MUCL3
# 7   3.984380e-97 0.7486267 0.998 0.733  7.270298e-93 4       TFF1
# 8   1.867996e-92 0.7204029 0.958 0.568  3.408532e-88 4       TFF2
# 9   2.187846e-91 0.4984619 0.696 0.289  3.992162e-87 4       AKR1B10
# 10  9.192596e-87 0.5475430 0.971 0.659  1.677373e-82 4       MUC1
# 11  3.680584e-84 0.3795960 0.575 0.206  6.715961e-80 4       VSIG1
# 12  6.894267e-83 0.3727592 0.528 0.174  1.257997e-78 4       KLF2
# 13  8.626138e-82 0.6241957 0.967 0.626  1.574011e-77 4       PSCA
# ...

# %% [markdown]
# # #5 ダメージうけてる？？

# %%
stomach.markers %>% filter(cluster==5)
# Out:
#     p_val         avg_logFC pct.1 pct.2 p_val_adj     cluster gene
# 1   2.591078e-198 0.9765315 0.800 0.220 4.727941e-194 5       HSP90AA1
# 2   2.289955e-183 1.7201042 0.971 0.614 4.178482e-179 5       RPL19
# 3   4.788496e-181 1.0756476 0.865 0.300 8.737568e-177 5       S100A10
# 4   4.408623e-176 0.6616235 0.632 0.128 8.044414e-172 5       PSMA7
# 5   4.513573e-167 1.1692418 0.857 0.349 8.235917e-163 5       TXN
# 6   6.435965e-167 0.6328164 0.558 0.103 1.174371e-162 5       IFITM3
# 7   1.232376e-145 1.0899977 0.966 0.580 2.248716e-141 5       RPS2
# 8   1.926321e-145 0.9406227 0.998 0.828 3.514958e-141 5       RPS18
# 9   1.671510e-140 0.8960265 0.821 0.337 3.050004e-136 5       PPIA
# 10  2.887865e-135 0.3404493 0.307 0.031 5.269487e-131 5       CKS1B
# 11  5.101532e-128 0.8129246 0.868 0.399 9.308766e-124 5       RPS7
# 12  1.359170e-127 0.9578809 0.944 0.603 2.480077e-123 5       RPS3
# 13  1.130143e-120 1.0708666 0.857 0.411 2.062171e-116 5       RPL7A
# ...

# %% [markdown]
# # #6 MUC6多い→foveolarじゃなくて胃底腺のほうとか

# %%
stomach.markers %>% filter(cluster==6)
# Out:
#     p_val         avg_logFC pct.1 pct.2 p_val_adj     cluster gene
# 1    0.000000e+00 2.1310298 0.650 0.059  0.000000e+00 6       MUC6
# 2   1.320779e-217 1.8036366 0.865 0.274 2.410025e-213 6       PGC
# 3   3.872619e-212 0.3812773 0.329 0.016 7.066368e-208 6       FUT9
# 4   9.602944e-208 2.1603847 0.625 0.107 1.752249e-203 6       LIPF
# 5   3.100642e-205 0.7808049 0.641 0.108 5.657742e-201 6       SLC12A2
# 6   8.481538e-197 0.4675087 0.448 0.046 1.547626e-192 6       CLU
# 7   9.268193e-196 1.4755666 0.559 0.086 1.691167e-191 6       AC020656.1
# 8   5.600336e-153 0.9466800 0.252 0.014 1.021893e-148 6       LTF
# 9   1.543686e-142 1.0286199 0.986 0.763 2.816763e-138 6       RPL34
# 10  2.643363e-138 0.8010957 0.869 0.338 4.823344e-134 6       RPL36A
# 11  2.735823e-136 1.0175175 0.991 0.927 4.992057e-132 6       RPL41
# 12  5.506673e-134 0.7307650 0.807 0.269 1.004803e-129 6       RPL17
# 13  1.587411e-131 0.4870799 0.483 0.090 2.896549e-127 6       SOX9
# ...

# %% [markdown]
# # #7 ダメージうけてる？？

# %%
stomach.markers %>% filter(cluster==7)
# Out:
#    p_val        avg_logFC pct.1 pct.2 p_val_adj    cluster gene
# 1  2.165688e-45 0.5585752 0.778 0.485 3.951730e-41 7       S100A11
# 2  1.048280e-41 0.6893500 0.960 0.801 1.912796e-37 7       S100A6
# 3  1.468671e-33 0.7087467 0.804 0.630 2.679883e-29 7       AGR2
# 4  2.393786e-31 0.8165423 0.636 0.404 4.367942e-27 7       MT1G
# 5  3.896999e-31 0.4824260 0.986 0.953 7.110853e-27 7       TMSB4X
# 6  7.417837e-30 0.5328150 0.866 0.648 1.353533e-25 7       S100P
# 7  1.997506e-26 0.7515349 0.901 0.750 3.644850e-22 7       TFF1
# 8  4.614217e-25 0.4904425 0.463 0.246 8.419562e-21 7       MT1X
# 9  6.326542e-24 0.3253334 0.972 0.929 1.154404e-19 7       RPL41
# 10 7.640177e-24 0.4313241 0.597 0.395 1.394103e-19 7       SEC61G
# 11 1.964221e-22 0.3435537 0.906 0.787 3.584115e-18 7       RPS29
# 12 8.487698e-22 0.3748597 0.608 0.404 1.548750e-17 7       FXYD3
# 13 1.585510e-21 0.3991498 0.469 0.266 2.893080e-17 7       MT1E
# ...

# %% [markdown]
# # #8
# #    Diabetes-associated protein in insulin-sensitive tissues,

# %%
stomach.markers %>% filter(cluster==8)
# Out:
#     p_val         avg_logFC pct.1 pct.2 p_val_adj     cluster gene
# 1   1.021311e-170 1.1424574 0.519 0.066 1.863585e-166 8       CKB
# 2   1.035214e-127 1.1546225 0.836 0.327 1.888955e-123 8       ATP5MD
# 3   1.782778e-126 1.1655980 0.972 0.708 3.253034e-122 8       ATP5F1E
# 4   3.937921e-126 1.3174249 0.991 0.782 7.185525e-122 8       FTH1
# 5   6.444649e-126 1.2159082 0.752 0.249 1.175955e-121 8       CYCS
# 6   1.221944e-122 1.1386602 0.915 0.522 2.229681e-118 8       ATP5ME
# 7   2.279543e-119 1.1003628 0.931 0.491 4.159482e-115 8       COX7C
# 8   2.045098e-110 1.0619826 0.824 0.334 3.731690e-106 8       COX7B
# 9   8.126857e-107 1.1037022 0.770 0.302 1.482908e-102 8       UQCRB
# 10  4.103042e-100 1.1798404 0.726 0.278  7.486821e-96 8       SLC25A5
# 11  4.945643e-100 1.0976326 0.994 0.952  9.024314e-96 8       TMSB4X
# 12   1.288989e-98 0.9693506 0.811 0.370  2.352019e-94 8       ATP5MPL
# 13   8.068024e-97 1.1115605 0.805 0.353  1.472172e-92 8       NDUFA4
# ...

# %% [markdown]
# # #9 chief

# %%
stomach.markers %>% filter(cluster==9)
# Out:
#    p_val         avg_logFC pct.1 pct.2 p_val_adj     cluster gene
# 1  3.698127e-166 2.6226825 0.741 0.122 6.747972e-162 9       LIPF
# 2  6.342084e-160 0.9548800 0.421 0.033 1.157240e-155 9       PGA3
# 3  1.031803e-159 2.2447682 0.583 0.072 1.882730e-155 9       PGA4
# 4  8.204479e-159 2.7193372 0.487 0.048 1.497071e-154 9       PGA5
# 5   4.154803e-89 2.7428388 0.803 0.301  7.581268e-85 9       PGC
# 6   3.590023e-87 0.5796468 0.434 0.069  6.550715e-83 9       MT1F
# 7   2.159819e-70 1.6935345 0.846 0.401  3.941022e-66 9       MT1G
# 8   6.396145e-60 1.2095605 0.654 0.243  1.167105e-55 9       MT1X
# 9   1.088276e-45 1.0161142 0.719 0.339  1.985777e-41 9       MT2A
# 10  1.053344e-39 0.6457163 0.947 0.774  1.922037e-35 9       RPL34
# 11  4.699325e-38 0.6897179 0.605 0.265  8.574858e-34 9       MT1E
# 12  3.616784e-36 0.5176012 0.952 0.753  6.599545e-32 9       RPS28
# 13  9.342136e-35 0.5323195 0.969 0.751  1.704660e-30 9       RPS27A
# ...

# %% [markdown]
# # #10 parietal cell

# %%
stomach.markers %>% filter(cluster==10)
# Out:
#     p_val         avg_logFC pct.1 pct.2 p_val_adj     cluster gene
# 1    0.000000e+00 2.5136575 0.858 0.025  0.000000e+00 10      ATP4A
# 2    0.000000e+00 2.2200488 0.835 0.026  0.000000e+00 10      ATP4B
# 3    0.000000e+00 1.8425424 0.843 0.028  0.000000e+00 10      GIF
# 4    0.000000e+00 1.2445107 0.685 0.017  0.000000e+00 10      MFSD4A
# 5    0.000000e+00 0.9732133 0.701 0.008  0.000000e+00 10      GPR155
# 6    0.000000e+00 0.6351204 0.567 0.009  0.000000e+00 10      SLC16A7
# 7    0.000000e+00 0.4609888 0.362 0.002  0.000000e+00 10      DNER
# 8   3.214812e-307 1.2163451 0.772 0.035 5.866067e-303 10      CLIC6
# 9   2.597563e-256 0.7873392 0.614 0.025 4.739774e-252 10      ESRRG
# 10  2.478120e-232 0.2938060 0.291 0.003 4.521825e-228 10      KIT
# 11  7.032904e-197 1.0001940 0.598 0.034 1.283294e-192 10      IGFBP5
# 12  1.160155e-188 0.3807475 0.299 0.006 2.116934e-184 10      AQP4
# 13  3.369250e-187 0.4901973 0.472 0.020 6.147870e-183 10      LIFR
# ...

# %% [markdown]
# # #11 腸上皮化生

# %%
stomach.markers %>% filter(cluster==11)
# Out:
#    p_val         avg_logFC pct.1 pct.2 p_val_adj     cluster gene
# 1   0.000000e+00 2.5183594 0.957 0.012  0.000000e+00 11      MUC2
# 2   0.000000e+00 2.1529139 0.771 0.005  0.000000e+00 11      CLCA1
# 3   0.000000e+00 1.5777030 0.714 0.008  0.000000e+00 11      ITLN1
# 4  1.584148e-186 3.6876812 0.943 0.065 2.890595e-182 11      SPINK4
# 5  7.320230e-142 1.8555471 0.657 0.037 1.335722e-137 11      ZG16
# 6  7.324264e-104 0.6587162 0.500 0.028  1.336458e-99 11      KLK1
# 7  8.411029e-104 3.1957646 0.986 0.157  1.534761e-99 11      TFF3
# 8   4.013068e-94 0.4525459 0.357 0.015  7.322645e-90 11      LRRC26
# 9   3.902207e-87 1.9216457 0.900 0.130  7.120357e-83 11      REG4
# 10  1.299393e-69 0.3899026 0.429 0.031  2.371003e-65 11      SPDEF
# 11  2.110844e-57 2.8469300 0.986 0.357  3.851658e-53 11      FCGBP
# 12  1.696970e-53 0.4768417 0.500 0.057  3.096461e-49 11      ST6GALNAC1
# 13  2.594840e-49 0.2724628 0.300 0.022  4.734805e-45 11      AQP3
# ...

# %%
# 0,1,2,4 foveolar
# 3 APOA1-4とか作ってるやつ
# 5 HSP出ている→損傷した腺細胞
# 6 MUC6多め→胃底腺側の腺細胞
# 7 よくわからない
# 8 これもよくわからない
# 9 chief cell
# 10 parietal cell
# 11 腸上皮化生

# %% [markdown]
# ## foveolarのみを取り出す
# ## parietal cell, 腸上皮化生, chief cellは分離
# ## 他のものはもう１回umap
